# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import sklearn.metrics
x,y=make_regression(n_samples=100,n_features=2,n_informative=2,n_targets=1,noise=50)
df=pd.DataFrame({'f1':x[:,0],'f2':x[:,1],'target':y})
fig= px.scatter_3d(df,x='f1',y='f2',z='target')
fig.show()

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
     

X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)
print(X.shape)     

df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})
     

print(df.shape)
     

print(df.head())
     


fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()
     

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)
print(X_test.shape)   

from sklearn.linear_model import LinearRegression
     

lr = LinearRegression()
     

lr.fit(X_train,y_train)
     
#LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

y_pred = lr.predict(X_test)
     

print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
     


x = np.linspace(-10, 10, 20)
y = np.linspace(-10, 10, 20)
print(x.shape)
xGrid, yGrid = np.meshgrid(y, x)
final=np.c_[xGrid.ravel(),yGrid.ravel()]
print(final.shape)
z_final = lr.predict(final).reshape(xGrid.shape)
z = z_final

#final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
print(xGrid.shape) 

fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()
     

lr.coef_
     
#array([59.64518074, 13.20409431])

lr.intercept_
     
#-7.55491251398082
# Out:
# (100, 2)
# (100, 3)
#    feature1  feature2      target
# 0 -0.043335 -1.062784  -73.238748
# 1  1.733023 -0.578440  113.582513
# 2 -1.344645 -1.494798  -19.589589
# 3  2.499279 -1.248606   42.938863
# 4 -0.232189  0.218486    0.901753
# (20, 2)
# MAE 39.25372256438062
# MSE 2421.1699567419123
# R2 score 0.48422239592789174
# (20,)
# (400, 2)
# (20, 20)
# -6.082275056432474

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Generate synthetic data
X, y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)
df = pd.DataFrame({'feature1': X[:, 0], 'feature2': X[:, 1], 'target': y})

# Create scatter plot
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# Fit the model
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# Define the grid
x = np.linspace(-10, 10, 20)
y = np.linspace(-10, 10, 20)
xGrid, yGrid = np.meshgrid(y, x)
final = np.c_[xGrid.ravel(), yGrid.ravel()]

# Predict the surface
z_final = lr.predict(final).reshape(xGrid.shape)

# Add surface to the scatter plot
fig.add_trace(go.Surface(x=xGrid, y=yGrid, z=z_final, colorscale='viridis'))

# Show the combined plot
fig.show()
